# %% [markdown]
# # 0.(1 microsecond by instruction)
# Asuuming that you can execute a million instructions $10^6$ every second, i.e. each instruction takes one microsecond $1\mu s=10^{-6}$ seconds. If you have algorithms take $\bf{ Time\ Complexity}$ steps to solve a problem of size $n$ as specified in column one. What is the size of the largest problem that you can solve in the time specified in row one?
#
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \lg(n) &  10^{1000000}   & 10^{60000000}  & 10^{3.6*10^{9}}  & 10^{8.64*10^{10}}  & 10^{3.15*10^{13}}  & 10^{3.15*10^{15}}  & 10^{3.15*10^{16}}  \\
#    \hline\\
# \lg^2(n) &  2^{1000000}  & 2^{60000000}  & 2^{3.6*10^{9}}  & 2^{8.64*10^{10}}  & 2^{3.15*10^{13}}  & 2^{3.15*10^{15}}  & 2^{3.15*10^{16}}  \\
#    \hline\\
# \sqrt{n} &  10^{12}  & 3.6*10^{15}  & 1.3*10^{19} & 7.46*10^{21} & 9.92*10^{26} & 9.92*10^{30} & 9.92*10^{32} \\
#  \hline
#  n &  10^{6}  & 6*10^{7} & 3.6*10^{9} & 8.64*10^{10} & 3.15*10^{13} & 3.15*10^{15} & 3.15*10^{16} \\
#  \hline
#  n\lg(n) &    &   &  &  &  &  &  \\
#  \hline
#  n^2 &  10^{3}  & 7745 & 6*10^{4} & 293938 & 5612486 & 56124860 & 177482393 \\
#  \hline
#   n^3 & 10^{2}  & 391  & 1532 & 4420 & 31581 & 146589 & 315817 \\
#  \hline
#   n^4 &  31  & 88  & 244 & 542 & 2369 & 7491 & 13322 \\
#  \hline
#   2^n &  19  & 25  & 31 & 36 & 44 & 51 & 54 \\
#  \hline
#  n! & 9   & 11  & 12 & 13 & 16 & 17 & 18 \\
#  \hline
#  n^n &  7  &  8 & 9 & 10 & 12 & 13 & 14 \\
#  \hline
# \end{array}
# $$

# %% [markdown]
# # 1.(10  nanoseconds by instruction)
#
# Asuuming that you can execute a 100 million instructions $100 \times 10^6$ every second, i.e. each instrcution takes 10 nanoseconds, 10 $\eta s  = 10^{-8} s $. If you have algorithms take $\bf{ Time\ Complexity}$ steps to solve a poblem of size $n$ as specified in column one. What is the size of the largest porblem that you can solve in the time specified in row one?
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \lg(n) &  10^{100*10^6}  & 10^{6*10^9}  & 10^{3.6*10^{11}} & 10^{8.64*10^{12}} & 10^{3.65*10^{15}} & 10^{3.15*10^{17}} & 10^{3.15*10^{18}} \\
#    \hline\\
# \lg^2(n) &  2^{100*10^6}  & 2^{6*10^9}  & 2^{3.6*10^{11}} & 2^{8.64*10^{12}} & 2^{3.65*10^{15}} & 2^{3.15*10^{17}} & 2^{3.15*10^{18}}  \\
#    \hline\\
# \sqrt{n} & 10^{16}  & 3.6*10^{19}  & 1.29*10^{23} & 7.46*10^{25} & 1.33*10^{31} & 1.33*10^{35} & 1.33*10^{37} \\
#  \hline
#  n &  100*10^6  & 6*10^9  & 3.6*10^{11} & 8.64*10^{12} & 3.65*10^{15} & 3.15*10^{17} & 3.15*10^{18} \\
#  \hline
#  n\lg(n) &    &   &  &  &  &  &  \\
#  \hline
#  n^2 &  10^{4}  & 77459  & 6*10^{5} & 2939387 & 60415229 & 604152298 &  1910497317\\
#  \hline
#   n^3 &  464  & 1817  & 7113 & 20519 & 153968 & 714656 & 1539681 \\
#  \hline
#   n^4 & 10^{2}  & 278  & 774 & 1714 & 7772 & 24579 & 43709 \\
#  \hline
#   2^n &  26  & 32  & 38 & 42 & 51 & 58 & 61 \\
#  \hline
#  n! &  11  & 12  & 14 & 15 & 17 & 19 & 20 \\
#  \hline
#  n^n &  8  & 9  & 11 & 11 & 13 & 14 & 15 \\
#  \hline
# \end{array}
# $$

# %% [markdown]
# # 2.(2.5  nanoseconds by instruction)
#
# Asuuming that you can execute a 400 million instructions $400 \times 10^6$ every second, i.e. each instrcution takes 2.5  nanoseconds, 2.5 $\eta s  = 2.5 \times 10^{-9} s$. If you have algorithms take $\bf{ Time\ Complexity}$ steps to solve a problem of size $n$ as specified in column one. What is the size of the largest problem that you can solve in the time specified in row one?
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \lg(n) &  10^{4*10^{8}}  &  10^{2.4*10^{10}} & 10^{1.44*10^{12}} & 10^{3.45*10^{13}} & 10^{1.26*10^{16}} & 10^{1.26*10^{18}} & 10^{1.26*10^{19}} \\
#    \hline\\
# \lg^2(n) &  2^{4*10^{8}}  &  2^{2.4*10^{10}} & 2^{1.44*10^{12}} & 2^{3.45*10^{13}} & 2^{1.26*10^{16}} & 2^{1.26*10^{18}} & 2^{1.26*10^{19}} \\
#    \hline\\
# \sqrt{n} &  1.6*10^{17}  & 5.76*10^{20} & 2*10^{24}  & 1.19*10^{27}  &  1.6*10^{32} & 1.6*10^{36} & 1.6*10^{38} \\
#  \hline
#  n &  4*10^{8}  & 2.4*10^{10}  & 1.44*10^{12} & 3.45*10^{13} & 1.26*10^{16} & 1.26*10^{18} & 1.26*10^{19} \\
#  \hline
#  n\lg(n) &    &   &  &  &  &  &  \\
#  \hline
#  n^2 &  2*10^{4}  & 154919  & 1.2*10^{6} & 5873670 & 112249721 & 1122497216 & 3549647870 \\
#  \hline
#   n^3 & 736 & 2884  & 11292 & 32554 & 232696 & 1080082 & 2326966 \\
#  \hline
#   n^4 & 141 & 393 & 1095 & 2423 & 10594 & 33503 & 59578 \\
#  \hline
#   2^n &  28  & 34  & 40 & 44 & 53 & 60 & 63 \\
#  \hline
#  n! &  11  & 13 & 15 & 16 & 18 & 19 & 20 \\
#  \hline
#  n^n &  9  & 10  & 11 & 12 & 14 & 15 & 15 \\
#  \hline
# \end{array}
# $$

# %% [markdown]
# # 3. (1 noneosecond by instruction)
#
# Asuuming that you can execute a 1000 million instructions $10^9$ every second, i.e. each instrcution takes 1  nanosecond, 1 $\eta s  = 10^{-9} s$. If you have algorithms take $\bf{ Time\ Complexity}$ steps to solve a problem of size $n$ as specified in column one. What is the size of the largest problem that you can solve in the time specified in row one?
# $$
# \begin{array}{|c|c|c|c|c|c|c|c|}
#  \hline
#  \bf{ Time\ Complexity} & Second  & Minute  & Hour & Day & Year & Century & Mileniun  \\
#   \hline\\
# \lg(n) & 10^{10^{9}} & 10^{6*10^{10}}  & 10^{3.6*10^{12}} & 10^{8.64*10^{13}} & 10^{3.15*10^{16}} & 10^{3.15*10^{18}} & 10^{3.15*10^{19}} \\
#    \hline\\
# \lg^2(n) & 2^{10^{9}} & 2^{6*10^{10}}  & 2^{3.6*10^{12}} & 2^{8.64*10^{13}} & 2^{3.15*10^{16}} & 2^{3.15*10^{18}} & 2^{3.15*10^{19}} \\
#    \hline\\
# \sqrt{n} &  10^{18}  & 3.6*10^{21} & 1.29*10^{25} & 7.5*10^{27} & 9.92*10^{32} & 9.92*10^{36} & 9.92*10^{38} \\
#  \hline
#  n &  10^{9} & 6*10^{10} & 3.6*10^{12} & 8.64*10^{13} & 3.15*10^{16} & 3.15*10^{18} & 3.15*10^{19} \\
#  \hline
#  n\lg(n) &    &   &  &  &  &  &  \\
#  \hline
#  n^2 &  31622  & 244948  & 1897366 & 9295160 & 177482393 & 1774823935 & 5612486080 \\
#  \hline
#   n^3 &  10^{3}  & 3914 & 15326 & 44208 & 315817 & 1465897 & 3158179 \\
#  \hline
#   n^4 & 177 & 494 & 1377 & 3048 &  13322 & 42128 & 74916 \\
#  \hline
#   2^n &  29  & 35 & 41 & 46 & 54 & 61 & 64 \\
#  \hline
#  n! &  12  & 13  & 15 & 16 & 18 & 20 & 20 \\
#  \hline
#  n^n &  9  & 10  & 11 & 13 & 14 & 15 & 16\\
#  \hline
# \end{array}
# $$
